# %%
print("Day 1 starts")
# Out:
# Day 1 starts

# %%
'Alice'+"Bob"
# Out:
# 'AliceBob'

# %%
print('Hello world!')
print('What is your name?') # ask for their name
myName = input()
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
# Out:
# Hello world!
# What is your name?
#  Bhanu
# It is good to meet you, Bhanu
# The length of your name is:
# 5
